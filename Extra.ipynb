# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([3,4,5,6,7,8,9])
y=np.array([62,85,3,565,512,156,419])

plt.plot(x,y, marker="x", ms=10, mec="red",linestyle="dashed",color="black",linewidth="3")
plt.show()
